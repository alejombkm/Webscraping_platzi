# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{artist_id}'

# %%
id_ameli = '4iyqyvWXO734GUNLTTnrPQ'

# %%
url_base+ep_artist.format(artist_id = id_ameli)
# Out:
# 'https://api.spotify.com/v1/artists/4iyqyvWXO734GUNLTTnrPQ'

# %%
import requests

# %%
r = requests.get(url_base+ep_artist.format(artist_id = id_ameli))

# %%
r.status_code
# Out:
# 401

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type':'client_credentials'}

# %%
headers = {'Authorization':'Basic ZDY4OTMzNjEwNDIwNDdiZjg4NGVmNGE3ZTE1ZWIxNGM6MGI5MDYzMzgzOTVhNDRkN2JiOTNlYzhjNGM4NTZjYzE='}

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQBiA3lFsb6e5FSaIbv3_CMh8-hpWSLLuxfmYmrF6etZGcuZYleCIz0n8GHV5yXTXkvauvUL6wMDwnQouVmH9CDBgQ5giuWWTlsifCjaVFGmaqpHx3c',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
token = r.json()['access_token']

# %%
token
# Out:
# 'BQBiA3lFsb6e5FSaIbv3_CMh8-hpWSLLuxfmYmrF6etZGcuZYleCIz0n8GHV5yXTXkvauvUL6wMDwnQouVmH9CDBgQ5giuWWTlsifCjaVFGmaqpHx3c'

# %%
headers = {'Authorization':'Bearer {}'.format(token)}
r = requests.get(url_base+ep_artist.format(artist_id = id_ameli), headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4iyqyvWXO734GUNLTTnrPQ'},
#  'followers': {'href': None, 'total': 39529},
#  'genres': ['dark minimal techno', 'minimal dub', 'techno'],
#  'href': 'https://api.spotify.com/v1/artists/4iyqyvWXO734GUNLTTnrPQ',
#  'id': '4iyqyvWXO734GUNLTTnrPQ',
#  'images': [{'height': 667,
#    'url': 'https://i.scdn.co/image/05d990aacd90d7936c828e5d721e1eaa5d1e25c4',
#    'width': 1000},
#   {'height': 427,
#    'url': 'https://i.scdn.co/image/2bc7a1ffc4c533a5bee9078d5dbd4361a38cf174',
#    'width': 640},
#   {'height': 133,
#    'url': 'https://i.scdn.co/image/6e50950b1b1e657c1db20ab19a8a424e480957f1',
#    'width': 200},
#   {'height': 43,
#    'url': 'https://i.scdn.co/image/37eb41741e5f361d98d85cfa2885d08dbe4eeb8f',
#    'width': 64}],
#  'name': 'Perc',
#  'popularity': 26,
#  'type': 'artist',
#  'uri': 'spotify:artist:4iyqyvWXO734GUNLTTnrPQ'}

# %%
url_search = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':"Perc",'type':'artist'}

# %%
search = requests.get(url_search, headers=headers,params=search_params)

# %%
search.status_code
# Out:
# 200

# %%
search.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Perc&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rRmDmzPcAFwcUDvG5gBqO'},
#     'followers': {'href': None, 'total': 485635},
#     'genres': ['classic soul', 'rock-and-roll', 'soul', 'southern soul'],
#     'href': 'https://api.spotify.com/v1/artists/3rRmDmzPcAFwcUDvG5gBqO',
#     'id': '3rRmDmzPcAFwcUDvG5gBqO',
#     'images': [{'height': 746,
#       'url': 'https://i.scdn.co/image/f7f4c9cd6e8389824de99e80202caf249c9e013b',
#       'width': 696},
#      {'height': 686,
#       'url': 'https://i.scdn.co/image/5419fb20b88695f910e0acf26b0ac5c37be4fc01',
#       'width': 640},
#      {'height': 214,
#       'url': 'https://i.scdn.co/image/b07fb5f1ad074aaa0209cbfbe962aa45f4a88121',
#       'width': 200},
#      {'height': 69,
#       'url': 'https://i.scdn.co/image/0625b1a3e938f0a64ff05243d68b4af09b152a0e',
#       'width': 64}],
#     'name': 'Percy Sledge',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:3rRmDmzPcAFwcUDvG5gBqO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#     'followers': {'href': None, 'total': 62995},
#     'genres': ['easy listening', "man's orchestra"],
#     'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#     'id': '24DQLSng7bKZD4GXLIaQbv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb79058cfc754be16c2f0070aa',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517479058cfc754be16c2f0070aa',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17879058cfc754be16c2f0070aa',
#       'width': 160}],
#     'name': 'Percy Faith & His Orchestra',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vATWjWf6AYUj0tyKD6sDM'},
#     'followers': {'href': None, 'total': 49404},
#     'genres': ['polish folk metal',
#      'polish metal',
#      'slavic folk metal',
#      'slavic metal'],
#     'href': 'https://api.spotify.com/v1/artists/4vATWjWf6AYUj0tyKD6sDM',
#     'id': '4vATWjWf6AYUj0tyKD6sDM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebb8fe87ff1a728d4d399a863b',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174b8fe87ff1a728d4d399a863b',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178b8fe87ff1a728d4d399a863b',
#       'width': 160}],
#     'name': 'Percival Schuttenbach',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:4vATWjWf6AYUj0tyKD6sDM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0wwMBDAxbnSYG9orbBeOLH'},
#     'followers': {'href': None, 'total': 4824},
#     'genres': ['baton rouge rap'],
#     'href': 'https://api.spotify.com/v1/artists/0wwMBDAxbnSYG9orbBeOLH',
#     'id': '0wwMBDAxbnSYG9orbBeOLH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb7494e134c2d3cb0ac5e3735a',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051747494e134c2d3cb0ac5e3735a',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1787494e134c2d3cb0ac5e3735a',
#       'width': 160}],
#     'name': 'Percy Keith',
#     'popularity': 26,
#     'type': 'artist',
#     'uri': 'spotify:artist:0wwMBDAxbnSYG9orbBeOLH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SssP1SxjhNyO65gR6J8Zo'},
#     'followers': {'href': None, 'total': 1576},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4SssP1SxjhNyO65gR6J8Zo',
#     'id': '4SssP1SxjhNyO65gR6J8Zo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d6c4b96bddd6f66a4b1b90da',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d6c4b96bddd6f66a4b1b90da',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d6c4b96bddd6f66a4b1b90da',
#       'width': 64}],
#     'name': 'percyzs',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:4SssP1SxjhNyO65gR6J8Zo'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4iyqyvWXO734GUNLTTnrPQ'},
#     'followers': {'href': None, 'total': 39529},
#     'genres': ['dark minimal techno', 'minimal dub', 'techno'],
#     'href': 'https://api.spotify.com/v1/artists/4iyqyvWXO734GUNLTTnrPQ',
#     'id': '4iyqyvWXO734GUNLTTnrPQ',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/05d990aacd90d7936c828e5d721e1eaa5d1e25c4',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/2bc7a1ffc4c533a5bee9078d5dbd4361a38cf174',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/6e50950b1b1e657c1db20ab19a8a424e480957f1',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/37eb41741e5f361d98d85cfa2885d08dbe4eeb8f',
#       'width': 64}],
#     'name': 'Perc',
#     'popularity': 26,
#     'type': 'artist',
#     'uri': 'spotify:artist:4iyqyvWXO734GUNLTTnrPQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5KJD39tFeCCTo3bXyQSnSb'},
#     'followers': {'href': None, 'total': 231},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5KJD39tFeCCTo3bXyQSnSb',
#     'id': '5KJD39tFeCCTo3bXyQSnSb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb1994c7c3b6fca56b309f5dac',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051741994c7c3b6fca56b309f5dac',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1781994c7c3b6fca56b309f5dac',
#       'width': 160}],
#     'name': 'Percy',
#     'popularity': 43,
#     'type': 'artist',
#     'uri': 'spotify:artist:5KJD39tFeCCTo3bXyQSnSb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ijOFF3Zqg5pGXwzRRVf2y'},
#     'followers': {'href': None, 'total': 7},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4ijOFF3Zqg5pGXwzRRVf2y',
#     'id': '4ijOFF3Zqg5pGXwzRRVf2y',
#     'images': [],
#     'name': 'Perc',
#     'popularity': 10,
#     'type': 'artist',
#     'uri': 'spotify:artist:4ijOFF3Zqg5pGXwzRRVf2y'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6evVLxWyiwmi8gDtHn1Vzx'},
#     'followers': {'href': None, 'total': 9199},
#     'genres': ['australian classical',
#      'concert band',
#      'early modern classical',
#      'wind symphony'],
#     'href': 'https://api.spotify.com/v1/artists/6evVLxWyiwmi8gDtHn1Vzx',
#     'id': '6evVLxWyiwmi8gDtHn1Vzx',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/b43c570dd3475eb92f417edb7bc9026db11c2179',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/867f37fab744eeb90bb22453333eb813c77abfb5',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/f420d8e56de990bda680c8dd5e0c2923abe46b4c',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/9703695fa3ece475c72ca1d7007c0e0c9284bd9f',
#       'width': 64}],
#     'name': 'Percy Grainger',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:6evVLxWyiwmi8gDtHn1Vzx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Lr9b8gyVoMb6UuqxdwLv3'},
#     'followers': {'href': None, 'total': 1},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7Lr9b8gyVoMb6UuqxdwLv3',
#     'id': '7Lr9b8gyVoMb6UuqxdwLv3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e48060e6d5a320950d75c64a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e48060e6d5a320950d75c64a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e48060e6d5a320950d75c64a',
#       'width': 64}],
#     'name': 'Perc',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7Lr9b8gyVoMb6UuqxdwLv3'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOh5Hdrc5A8nQxBf5Q6gN'},
#     'followers': {'href': None, 'total': 12233},
#     'genres': ['alternative hip hop', 'bronx hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/3jOh5Hdrc5A8nQxBf5Q6gN',
#     'id': '3jOh5Hdrc5A8nQxBf5Q6gN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb3ae6e7e56bb331010a992d6e',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051743ae6e7e56bb331010a992d6e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1783ae6e7e56bb331010a992d6e',
#       'width': 160}],
#     'name': 'Percee P',
#     'popularity': 32,
#     'type': 'artist',
#     'uri': 'spotify:artist:3jOh5Hdrc5A8nQxBf5Q6gN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vixfiPEOndh08Ht4FBLN8'},
#     'followers': {'href': None, 'total': 9},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6vixfiPEOndh08Ht4FBLN8',
#     'id': '6vixfiPEOndh08Ht4FBLN8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebb5d3b5e044bea7a8acb2dbac',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174b5d3b5e044bea7a8acb2dbac',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178b5d3b5e044bea7a8acb2dbac',
#       'width': 160}],
#     'name': 'Perc',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6vixfiPEOndh08Ht4FBLN8'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6unIK8JFrGemCge3NIUDKE'},
#     'followers': {'href': None, 'total': 44971},
#     'genres': ['easy listening'],
#     'href': 'https://api.spotify.com/v1/artists/6unIK8JFrGemCge3NIUDKE',
#     'id': '6unIK8JFrGemCge3NIUDKE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730602fe9f0fd2a2c12987f262',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020602fe9f0fd2a2c12987f262',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510602fe9f0fd2a2c12987f262',
#       'width': 64}],
#     'name': 'Percy Faith',
#     'popularity': 40,
#     'type': 'artist',
#     'uri': 'spotify:artist:6unIK8JFrGemCge3NIUDKE'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/79GbKoBbsxLP52geYdT6CZ'},
#     'followers': {'href': None, 'total': 11},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/79GbKoBbsxLP52geYdT6CZ',
#     'id': '79GbKoBbsxLP52geYdT6CZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cf911b8a30dffbf27de3bf14',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cf911b8a30dffbf27de3bf14',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cf911b8a30dffbf27de3bf14',
#       'width': 64}],
#     'name': 'Perc',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:79GbKoBbsxLP52geYdT6CZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6XSqSvlKVGlir2CuRUwalA'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6XSqSvlKVGlir2CuRUwalA',
#     'id': '6XSqSvlKVGlir2CuRUwalA',
#     'images': [],
#     'name': 'Perc',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6XSqSvlKVGlir2CuRUwalA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0vKbTTNdtagd8xiERj6Szb'},
#     'followers': {'href': None, 'total': 1310},
#     'genres': ['jazz double bass'],
#     'href': 'https://api.spotify.com/v1/artists/0vKbTTNdtagd8xiERj6Szb',
#     'id': '0vKbTTNdtagd8xiERj6Szb',
#     'images': [{'height': 1015,
#       'url': 'https://i.scdn.co/image/a711b799e8ccc15dba9c1fb9eb122b4e2d1c98a7',
#       'width': 868},
#      {'height': 748,
#       'url': 'https://i.scdn.co/image/62d26653cedde95fe304fec36ee3a2679ea59c07',
#       'width': 640},
#      {'height': 234,
#       'url': 'https://i.scdn.co/image/ac83b10b65711abc366ec8c66a65c139434ec69d',
#       'width': 200},
#      {'height': 75,
#       'url': 'https://i.scdn.co/image/821eaa4e2752e5ab6d3abed56b1a20e1e5abe91d',
#       'width': 64}],
#     'name': 'Percy Heath',
#     'popularity': 31,
#     'type': 'artist',
#     'uri': 'spotify:artist:0vKbTTNdtagd8xiERj6Szb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xe1IGlvK52O5zZsmPvFSF'},
#     'followers': {'href': None, 'total': 1},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3Xe1IGlvK52O5zZsmPvFSF',
#     'id': '3Xe1IGlvK52O5zZsmPvFSF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736da6b1447653524974d340a7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026da6b1447653524974d340a7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516da6b1447653524974d340a7',
#       'width': 64}],
#     'name': 'Perc',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Xe1IGlvK52O5zZsmPvFSF'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jRxj4ywYBsZ8tdf69vlEO'},
#     'followers': {'href': None, 'total': 202},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6jRxj4ywYBsZ8tdf69vlEO',
#     'id': '6jRxj4ywYBsZ8tdf69vlEO',
#     'images': [],
#     'name': 'Percy P',
#     'popularity': 30,
#     'type': 'artist',
#     'uri': 'spotify:artist:6jRxj4ywYBsZ8tdf69vlEO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Oq7UillhHOJDxaskXXHRq'},
#     'followers': {'href': None, 'total': 12},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3Oq7UillhHOJDxaskXXHRq',
#     'id': '3Oq7UillhHOJDxaskXXHRq',
#     'images': [],
#     'name': 'Perc',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Oq7UillhHOJDxaskXXHRq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2CZkyihyuE9dEYbA1DTC45'},
#     'followers': {'href': None, 'total': 13},
#     'genres': ['instrumental lullaby'],
#     'href': 'https://api.spotify.com/v1/artists/2CZkyihyuE9dEYbA1DTC45',
#     'id': '2CZkyihyuE9dEYbA1DTC45',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27324c31810b80e0363759839b4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0224c31810b80e0363759839b4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485124c31810b80e0363759839b4',
#       'width': 64}],
#     'name': 'Percy Erickson',
#     'popularity': 28,
#     'type': 'artist',
#     'uri': 'spotify:artist:2CZkyihyuE9dEYbA1DTC45'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Perc&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 38}}

# %%
import pandas as pd

# %%
df = pd.DataFrame(search.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/3...
# 1  {'spotify': 'https://open.spotify.com/artist/2...
# 2  {'spotify': 'https://open.spotify.com/artist/4...
# 3  {'spotify': 'https://open.spotify.com/artist/0...
# 4  {'spotify': 'https://open.spotify.com/artist/4...
#
#                          followers  \
# 0  {'href': None, 'total': 485635}
# 1   {'href': None, 'total': 62995}
# 2   {'href': None, 'total': 49404}
# 3    {'href': None, 'total': 4824}
# 4    {'href': None, 'total': 1576}
#
#                                               genres  \
# 0  [classic soul, rock-and-roll, soul, southern s...
# 1                  [easy listening, man's orchestra]
# 2  [polish folk metal, polish metal, slavic folk ...
# 3                                  [baton rouge rap]
# 4                                                 []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/3rRmDmzPcAF...  3rRmDmzPcAFwcUDvG5gBqO
# 1  https://api.spotify.com/v1/artists/24DQLSng7bK...  24DQLSng7bKZD4GXLIaQbv
# 2  https://api.spotify.com/v1/artists/4vATWjWf6AY...  4vATWjWf6AYUj0tyKD6sDM
# 3  https://api.spotify.com/v1/artists/0wwMBDAxbnS...  0wwMBDAxbnSYG9orbBeOLH
# 4  https://api.spotify.com/v1/artists/4SssP1SxjhN...  4SssP1SxjhNyO65gR6J8Zo
#
#                                               images  \
# 0  [{'height': 746, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                           name  popularity    type  \
# 0                 Percy Sledge          54  artist
# 1  Percy Faith & His Orchestra          48  artist
# 2        Percival Schuttenbach          50  artist
# 3                  Percy Keith          26  artist
# 4                      percyzs          37  artist
#
#                                      uri
# 0  spotify:artist:3rRmDmzPcAFwcUDvG5gBqO
# 1  spotify:artist:24DQLSng7bKZD4GXLIaQbv
# 2  spotify:artist:4vATWjWf6AYUj0tyKD6sDM
# 3  spotify:artist:0wwMBDAxbnSYG9orbBeOLH
# 4  spotify:artist:4SssP1SxjhNyO65gR6J8Zo

# %%
df.loc[3]['id']
# Out:
# '0wwMBDAxbnSYG9orbBeOLH'

# %%
import base64

def get_token(client_id, client_secret):
    base_idS = client_id +b':'+ client_secret
    enconded = base64.b64encode(base_idS)
    params =  {'grant_type':'client_credentials'}
    headers = {'Authorization': 'Basic ' + str(enconded, 'utf-8')}
    token_url = 'https://accounts.spotify.com/api/token'
    r = requests.post(token_url, data=params, headers=headers)
    if r.status_code != 200:
        print('Error requests. ', r.json())
        return None
    print('Token valido por {} segundos. '.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
#Agregate credentials

# %%
token = get_token(client_id,client_secret)
# Out:
# Token valido por 3600 segundos.

# %%
headers = {'Authorization':'Bearer {}'.format(token)}
ep_albums = '/artists/{artist_id}/albums'
params = {'country': 'CO'}
album_perc = requests.get(url_base+ep_albums.format(artist_id = id_ameli), headers=headers, params= params)

# %%
list_albums = [(album['id'], album['name']) for album in album_perc.json()['items']]
list_albums
# Out:
# [('1qb1RqfAYwjFtJY803A00y', 'Bitter Music - Complete Edition'),
#  ('6BONIAmCIkb27SM2qOz0BO', 'Bitter Music'),
#  ('6JzoR70jUr3yfZWny0tldE', 'Videodrome'),
#  ('5iz9ATraeAkmWlFJW0GDQ3', 'The Power And The Glory'),
#  ('6Z8Ng1CZDNVjXALpeCXFl9', 'Wicker & Steel - The Complete Remixes'),
#  ('3AK0HIG0sop5jPmkwcPQEf', 'Wicker & Steel Remixed - EP2'),
#  ('3SYFrXqzLe5VtIKU68xxu6', 'Wicker & Steel'),
#  ('4KmsRSmevJQ2ubXAEerovD', 'Brevity (Perc Remix)'),
#  ('5dl47VPmEl1fSBd0xpm6hf', 'Resistor Remixed'),
#  ('3MxW0snkmoUJNMSbMcyfe0', 'Wave Cannon EP'),
#  ('4MllgEom7kcumjDcDmiYbh', 'Dirt'),
#  ('2qmFhWIfhjNw5XAtPMKlmB', 'Chains of Change'),
#  ('6eQD5tURGGR2cV29sWvWnz', 'Motorik'),
#  ('4e2G2s2qkx12Pv6Phq9eYe', 'Greed Dance'),
#  ('6WkqgfCaIzryd7V5YY1Pnd', 'Louder Than Chaos Vol. 2'),
#  ('2BbBAilBgjonR36b7eGOTW', 'Fire In Negative'),
#  ('3Ke4aq0r4PtVVJ5PXJhmPH', 'Look What Your Love Has Done To Me (Remixed)'),
#  ('1IZMVRkfnuHIuyBi8ahx0C', 'Three Tracks To Send To Your Ghost Producer'),
#  ('5sYWR3xOCelBQQEFESYxvi', "Hyperlink / London Isn't England Remixed"),
#  ('0WqgrPyj7QUeljJu70oxyj', 'Leather & Lace Remixed')]

# %%
ep_album = '/albums/{album_id}/tracks'
dirt_id = '4MllgEom7kcumjDcDmiYbh' 
dirt = requests.get(url_base+ep_album.format(album_id = dirt_id), headers=headers, params= params)

# %%
dirt.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iyqyvWXO734GUNLTTnrPQ'},
#     'href': 'https://api.spotify.com/v1/artists/4iyqyvWXO734GUNLTTnrPQ',
#     'id': '4iyqyvWXO734GUNLTTnrPQ',
#     'name': 'Perc',
#     'type': 'artist',
#     'uri': 'spotify:artist:4iyqyvWXO734GUNLTTnrPQ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 333802,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/63vZ9C4LDEobgdLvGTjDj7'},
#   'href': 'https://api.spotify.com/v1/tracks/63vZ9C4LDEobgdLvGTjDj7',
#   'id': '63vZ9C4LDEobgdLvGTjDj7',
#   'is_local': False,
#   'name': 'Dirt',
#   'preview_url': 'https://p.scdn.co/mp3-preview/200e1123a2f7867b8d17d8108e2e37fceaf2ebb3?cid=d6893361042047bf884ef4a7e15eb14c',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:63vZ9C4LDEobgdLvGTjDj7'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iyqyvWXO734GUNLTTnrPQ'},
#     'href': 'https://api.spotify.com/v1/artists/4iyqyvWXO734GUNLTTnrPQ',
#     'id': '4iyqyvWXO734GUNLTTnrPQ',
#     'name': 'Perc',
#     'type': 'artist',
#     'uri': 'spotify:artist:4iyqyvWXO734GUNLTTnrPQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/31XNv39TUPUq0Xpo7t5Qv8'},
#     'href': 'https://api.spotify.com/v1/artists/31XNv39TUPUq0Xpo7t5Qv8',
#     'id': '31XNv39TUPUq0Xpo7t5Qv8',
#     'name': 'EAS',
#     'type': 'artist',
#     'uri': 'spotify:artist:31XNv39TUPUq0Xpo7t5Qv8'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 314366,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7H5HQAOurEXU5TsPrFVHEA'},
#   'href': 'https://api.spotify.com/v1/tracks/7H5HQAOurEXU5TsPrFVHEA',
#   'id': '7H5HQAOurEXU5TsPrFVHEA',
#   'is_local': False,
#   'name': 'Dirt - Perc vs EAS Mix',
#   'preview_url': 'https://p.scdn.co/mp3-preview/6ef85e522bf1390dbe485d795b7ed1edccac0968?cid=d6893361042047bf884ef4a7e15eb14c',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:7H5HQAOurEXU5TsPrFVHEA'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iyqyvWXO734GUNLTTnrPQ'},
#     'href': 'https://api.spotify.com/v1/artists/4iyqyvWXO734GUNLTTnrPQ',
#     'id': '4iyqyvWXO734GUNLTTnrPQ',
#     'name': 'Perc',
#     'type': 'artist',
#     'uri': 'spotify:artist:4iyqyvWXO734GUNLTTnrPQ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 385393,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6m6ufM9xm7kys17bpJbtGq'},
#   'href': 'https://api.spotify.com/v1/tracks/6m6ufM9xm7kys17bpJbtGq',
#   'id': '6m6ufM9xm7kys17bpJbtGq',
#   'is_local': False,
#   'name': 'Dirt - Crowd Mix',
#   'preview_url': 'https://p.scdn.co/mp3-preview/888e68f1dc95d8c9f0c963daf8b41d6b971fd60d?cid=d6893361042047bf884ef4a7e15eb14c',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:6m6ufM9xm7kys17bpJbtGq'}]

# %%
dirt_track = [(track['id'], track['name']) for track in dirt.json()['items']]
dirt_track
# Out:
# [('63vZ9C4LDEobgdLvGTjDj7', 'Dirt'),
#  ('7H5HQAOurEXU5TsPrFVHEA', 'Dirt - Perc vs EAS Mix'),
#  ('6m6ufM9xm7kys17bpJbtGq', 'Dirt - Crowd Mix')]

# %%
#Create function to get discography
def get_discography(artist_id, token, return_name = False, page_limit = 50, country = None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    headers = {'Authorization':'Bearer {}'.format(token)}
    params = {'limit': page_limit,
              'offset':0,
              'country':country}
    
    lista = []
    r = requests.get(url , params= params, headers=headers)

    if r.status_code != 200:
        print('Error ', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [(item['id']) for item in r.json()['items']]

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=headers)
        
        if r.status_code != 200:
            print('Error ', r.json())
            return None

        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [(item['id']) for item in r.json()['items']]

    return lista

# %%
def get_tracks(album_id, token, return_name = False, page_limit = 50, market = None):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    headers = {'Authorization':'Bearer {}'.format(token)}
    params = {'limit': page_limit,
              'offset':0,
              'market':market}
    
    lista = []
    r = requests.get(url , params= params, headers=headers)

    if r.status_code != 200:
        print('Error ', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [(item['id']) for item in r.json()['items']]

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=headers)
        
        if r.status_code != 200:
            print('Error ', r.json())
            return None

        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [(item['id']) for item in r.json()['items']]

    return lista

# %%
for album in get_discography(id_ameli, token, return_name= True, country='CO'):
    print(album[1])
    for track in get_tracks(album[0], token, return_name =True,market='CO' ):
        print('/t', track[1])
# Out:
# Bitter Music - Complete Edition
# /t Exit
# /t Unelected
# /t Wax Apple
# /t Chatter
# /t I Just Can't Win
# /t The Thought That Counts
# /t Spit
# /t Rat Run
# /t Look What Your Love Has Done To Me
# /t After Ball
# /t Unelected - Dax J Remix
# /t Wax Apple - Lucy Remix
# /t Rat Run - Matrixxman Remix
# /t Look What Your Love Has Done To Me - I Hate Models Primitive Remix
# /t Look What Your Love Has Done To Me - Amelie Lens Remix
# /t Look What Your Love Has Done To Me - Perc VIP Mix
# /t The Thought That Counts - Head Front Panel Remix
# /t Chatter - Hodge Remix
# /t Exit - Pessimist Remix
# /t I Just Can't Win - Dale Cornish Remix
# Bitter Music
# /t Exit
# /t Unelected
# /t Wax Apple
# /t Chatter
# /t I Just Can't Win
# /t The Thought That Counts
# /t Spit
# /t Rat Run
# /t Look What Your Love Has Done To Me
# /t After Ball
# Videodrome
# /t Play
# /t Stop
# /t Fast Forward
# /t Rewind
# /t Pause
# The Power And The Glory
# /t Rotting Sound
# /t Speek
# /t Lurch
# /t Galloper
# /t David & George
# /t Horse Gum
# /t Dumpster
# /t Bleeding Colours
# /t Take Your Body Off
# /t A Living End
# Wicker & Steel - The Complete Remixes
# /t My Head Is Slowly Exploding - Ancient Methods Remix
# /t Start Chopping - Tommy Four Seven Remix
# /t Gonkle - Bitten By The Black Dog
# /t Choice - Walls Remix
# /t You Saw Me - Sigha & Truss Remix
# /t My Head Is Slowly Exploding - ASC Remix
# /t Pre-Steel - Tengui Remix
# /t You Saw Me - Cherry Rip mix by TVO
# /t My Head Is Slowly Exploding - Chris Carter Remix
# /t You Saw Me - Fife Free mix by TVO
# Wicker & Steel Remixed - EP2
# /t Choice - Walls Remix
# /t You Saw Me - Free Fife mix by TVO
# /t You Saw Me - Cherry Ripe mix by TVO
# /t Pre-Steel - Tengui Remix
# Wicker & Steel
# /t Choice
# /t My Head Is Slowly Exploding
# /t Start Chopping
# /t You Saw Me
# /t Pre-Steel
# /t Gonkle
# /t London, We Have You Surrounded
# /t Snow Chain
# /t Jmurph
# Brevity (Perc Remix)
# /t Brevity - Perc Remix
# Resistor Remixed
# /t Resistor
# /t Resistor - Tassid Remix
# /t Resistor - Jensen Interceptor's TNG Borg Remix
# /t Resistor - Wallis Remix
# Wave Cannon EP
# /t Wave Cannon - Original Mix
# /t Loose Fit - Original Mix
# /t Crowd Control - Original Mix
# Dirt
# /t Dirt
# /t Dirt - Perc vs EAS Mix
# /t Dirt - Crowd Mix
# Chains of Change
# /t Slew of Succession
# /t Slew of Succession - Perc Remix
# /t Evolution of Faces
# /t Rises the Red Moon
# Motorik
# /t Motorik
# Greed Dance
# /t Greed Dance
# /t Resistor
# /t 240 Volts
# Louder Than Chaos Vol. 2
# /t Carbon Black
# /t Schism
# Fire In Negative
# /t Fire In Negative
# /t E Mono
# /t Snare
# /t Destroyed By Jazz
# Look What Your Love Has Done To Me (Remixed)
# /t Look What Your Love Has Done To Me - I Hate Models Primitive Remix
# /t Look What Your Love Has Done To Me - Amelie Lens Remix
# /t Look What Your Love Has Done To Me - Perc VIP Mix
# Three Tracks To Send To Your Ghost Producer
# /t Toxic NRG
# /t Driller
# /t Pivot
# Hyperlink / London Isn't England Remixed
# /t Hyperlink - Tymon Remix
# /t London Isn't England - Ansome Remix
# Leather & Lace Remixed
# /t Leather & Lace - Ghost In The Machine Remix
# /t Leather & Lace - Pinch Remix
# /t Leather & Lace - Mumdance & Logos Remix
# Bitter Music Remixed EP02
# /t Unelected - Dax J Remix
# /t Wax Apple - Lucy Remix
# /t Rat Run - Matrixxman Remix
# Bitter Music Remixed EP01
# /t The Thought That Counts - Head Front Panel Remix
# /t Chatter - Hodge Remix
# /t Exit - Pessimist Remix
# /t I Just Can't Win - Dale Cornish Remix
# Igneous
# /t Igneous
# /t Breezeblock
# /t Flooring
# Temperature's Rising
# /t Temperature's Rising
# /t Temperate Dub
# Leather & Lace
# /t Leather & Lace
# /t Subox
# /t Badman
# Ma
# /t The Death of Rebirth
# /t Negative Space
# /t Ma
# Mutiny & Disorder
# /t Mutiny
# /t Disorder
# Gob
# /t Gob
# /t Gruel
# /t Change To Win
# Two Hundred
# /t Two Hundred
# /t Judd
# /t Forever Your Girl
# /t Van Der Valk
# The Power and the Glory Remixed
# /t Take Your Body Off - Tessela Remix
# /t Bleeding Colours - Untold Remix
# /t Dumpster - Clouds Remix
# Interpretations
# /t Sado Masodub
# /t Rivieradub
# /t Liebesdub
# /t Lunebest
# Ampere & Ohm
# /t Coulomb
# /t Dynes
# /t Joule
# Spiker
# /t Clapacid
# /t Spiker
# /t Broken
# Pure & Simple
# /t Pure & Simple - Original Mix
# /t Pure & Simple - Ben Sims Warehouse Remix
# /t Pure & Simple - Sawlin Remix
# /t Pure & Simple - Perc RZ Dub
# A New Brutality
# /t A New Brutality
# /t Cash 4 Gold
# /t Boy
# /t Before I Go
# Untitled
# /t She's the Disease - Original Mix
# /t Blinding Truth - Original Mix
# /t Forge - Original Mix
# /t Kater - Original Mix
# Wicker & Steel Remixed - EP1
# /t Start Chopping - Tommy Four Seven Remix
# /t Gonkle - Bitten By The Black Dog
# /t You Saw Me - Sigha & Truss Remix
# /t My Head Is Slowly Exploding - ASC Remix
# Quemadura Del Sol
# /t Quemadura Del Sol - Perc Remix
# My Head Is Slowly Exploding
# /t My Head Is Slowly Exploding
# /t My Head Is Slowly Exploding - Ancient Methods Remix
# /t My Head Is Slowly Exploding - Chris Carter Remix
# M Cargo EP
# /t M Cargo - Original Mix
# /t M Cargo - Jonas Kopp Remix
# /t Tower - Original Mix
# /t Tower - Perc's Tower Of Power Mix
# Slim / Chromamoan EP
# /t Slim
# /t Chromamoan
# /t Slim - DVS1 Four By Four Mix
# /t Slim - Reprise Tool
# Antifunk / Purple
# /t Antifunk
# /t Purple
# Dax
# /t Mendax
# /t Percdax
# /t Moddax
# Vertigo Part 2 - 1909
# /t 1909 - Millie's Dark Room Mix
# /t 1909 - Perc's Outboard Mix
# /t 1909
# /t 1909 - Derek Plaslaiko Remix
# Monad V
# /t Tension - Original Mix
# /t Rowan - Original Mix
# /t Stoq - Original Mix
# /t Bozo - Original Mix
# Vertigo Part 1 (BCG)
# /t BCG - Original Mix
# /t BCG - Milton Bradley Critical Level Mix
# /t BCG - Forward Strategy Group Remix
# /t BCG - Milton Bradley Beyond The Silence Mix
# Mathlete EP
# /t Mathlete
# /t Throb
# /t Math Beat
# Painted Yellow, Painted Black
# /t Painted Yellow, Painted Black
# /t Painted Yellow Painted Black - Perc Remix
# /t How Nice It Is
# /t How Nice It Is - Issakidis Dzir Remix
# Submit EP (Part 2)
# /t So Long 46
# /t So Long - Snare Tool
# /t Trojan Bumble
# /t Trojan Bumble - Knock Knock Tool
# Submit EP (Part 2)
# /t So Long 46
# /t So Long - Snare Tool
# /t Trojan Bumble
# /t Trojan Bumble - Knock Knock Tool
# Remix Collection Vol 8
# /t Look What Your Love Has Done To Me - Amelie Lens Remix
# /t 90s Hammer - DJ Boss Remix
# /t Hyperlink - Tymon Remix
# /t Leather & Lace - Ghost In The Machine Remix
# /t Look What Your Love Has Done To Me - Perc VIP Mix
# /t London Isn't England feat. Ewa Justka - Ansome Remix
# /t Spreading Plague - Perc Remix
# /t Leather & Lace - Mumdance & Logos Remix
# /t 90s Hammer - Perc Remix
# /t Look What Your Love Has Done To Me - I Hate Models Primitive Remix
# Collected Works
# /t Bliss
# /t Minit
# /t Pompus
# /t Rumode
# /t Silla
# /t Rinrk
# /t Pigs In Blankets
# /t Tanjers
# /t Moonshake
# /t Work Softer - Matador Remix
# /t Mistake Me - Matador Remix
# /t Night In The Jungle - Matador Remix
# Path Of Self destruction EP
# /t Path Of Self Destruction
# /t Broken Regimes
# /t Path Of Self Destruction - Perc Remix
# /t You Lost Me There For A Second
# /t Time Continuum
# So Far, So Good, So What
# /t Reality
# /t Identity - Gary Beck Remix
# /t Black Blade - Sasha Carassi Remix
# /t Blakout
# /t Punk
# /t Jovian System
# /t Caustic - Alex Bau Remix
# /t Krieg Maschine - Stigmata Remix
# /t Easy Meat - Original Mix
# /t Groove on Surface
# /t Contact - Vx Remix
# /t Attenuate - Audio Injection Remix
# /t Berlin Drone
# /t Complete
# /t Deterrent - Brian Sanhaji Remix
# /t Stovepipe - Alland Byallo Remix
# /t Horsey Ride - Alexi Delano Remix
# /t Mandrake - Dustin Zahn's Sunday Morning Dub
# /t Seven Seconds
# /t Hidden
# /t Overclock
# /t Ageha - Kyle Geiger Remix
# /t Identity - Mike Humphries Remix
# /t Screwdriver Part 2
# /t Toxic - Sasha Carassi Remix
# /t District
# /t 2nd Next
# /t Ratio - Tony Montana Remix
# /t Destroyer of Worlds - Floom Remix
# /t Latah
# /t Sulfur Skies
# /t Atavic - Flex Remix
# /t Ganimed - Adam Jay & Angel Alanis Remix
# /t Robin Hood Was the First Gangsta
# /t Elementary Particles
# /t Morfic
# /t Secret Places
# /t Outer Limits
# /t Cern
# /t Paranoia
# /t Nightworld
# /t Kelder
# /t Trans Lunar Injection - Niereich vs. Hackler & Kuch
# /t Room 47
# /t 3three - A-Brothers Remix
# /t Life Is Space - Tom Hades Remix
# /t Attraction - Extrawelt Remix
# Mixmag Germany - Episode 007: Egokind & Ozean
# /t Mixmag Germany - Episode 007
# /t Leaving
# /t Equation
# /t Snoi
# /t Do Me
# /t Matte - IMYRMIND Remix
# /t Hey Now Wait a Minute
# /t Glassbeadgames - 8 Hours at Fabric Dub
# /t Silverbird Wake Me Up
# /t Non
# /t Take Your Body Off - Tessela Remix
# /t What We Know - Motor City Drum Ensemble Remix
# /t Attack
# /t Initiate
# /t Everybody Dance Now
# /t Leap
# Interpretations On F.C. Judd
# /t Solid States
# /t Woodford
# /t Flip-Flop
# /t Control Sample
# /t Hoarded House - reMMix Fredit
# /t Space Judder
# /t Splice Block
# /t Slim Jim Wimshurst Mechanicals
# /t Judd Drums
# /t FJUDDmix 032013
# /t Concrete Teeth
# /t Fredwrek
# Perc Trax - Tracks Of 2017
# /t Look What Your Love Has Done To Me
# /t London Isn't England
# /t The Holy Grill
# /t Marching Powder
# /t Unelected
# /t Hold My Drink
# /t Poison Your Body
# /t Mephi
# 10 Years of Sleaze Records: The Remixes
# /t Bleeds - Perc Remix
# /t Layday - Mark Broom Remix
# /t Paretos Law - Robert S (PT) Remix
# /t New Beginnings - Manic Brothers Remix
# 100 Years No Fears
# /t Liberty
# /t Trick Me Off
# /t Take It Dere
# /t Free Da Goons
# /t Fuck It
# /t Mafia Shit
# /t Scared of Dat
# /t Mob Ties
# /t Still on 50
# /t Freestyle
# /t Baghdad
# /t Feeling Like Stacks
# /t Where to Start - Radio Edit
# /t Voices in my Head
# /t Panic
# DJ Hell (Remixed)
# /t Sprung Aus Den Wolken - David Duriez Brique Rouge Remix
# /t Sprung Aus Den Wolken - David Duriez's Favourite Tool
# /t Buttersaure - Perc Remix
# /t Sprung Aus Den Wolken - Pramface Remix
# Grassroots: United Over Ukraine
# /t Alta - Original Mix
# /t Krypt - Original Mix
# /t She Sleeps - Original Mix
# /t Anxiety - Original Mix
# /t Lost In Freedom - Original Mix
# /t Sett - Original Mix
# /t Re-Volya - Original Mix
# /t Kyv - Original Mix
# /t Eternal - Original Mix
# /t Right Through Me - Original Mix
# /t Shifting - Original Mix
# /t Wizards of the Lost Kingdom - Original Mix
# /t Falling Apart - Original Mix
# /t Resident - Original Mix
# Perc Trax: Tracks Of 2020
# /t Breaking The Seal
# /t E Mono
# /t Woodman
# /t The Wolves
# /t Plothole
# /t Scorched
# /t Zero
# /t Exploit Me I'm Yours
# /t Snare
# /t Raw Deal
# /t Fire In Negative
# /t Morning Sesh
# /t Juggernaut
# /t Planting Seeds
# V/A (Perc + Remco Beekwilder + UVB + Jerm)
# /t Skinner
# /t Dominance
# /t Gun And Run
# /t Flesh Hoover
# Perc Trax - Tracks Of 2014
# /t Brockweir
# /t Dumpster
# /t Blackstar
# /t Take Your Body Off
# /t Endless September
# /t Forever Your Girl
# /t Goves
# /t Raw Visions
# /t Two Hundred
# /t Radiate The Ocean From My Back
# Staring At All This Handle
# /t Staring At All This Handle - Original Mix
# /t Staring At All This Handle - Perc Remix
# /t Sky On The Floor - Original Mix
# /t Sky On The Floor - Dub
# /t Sky On The Floor - Volte-Face Remix
# RUDƎ 001
# /t RS 220 - Original
# /t Varna - Original
# /t Tool Time - Original
# /t IC - Original
# We'll Rave Again
# /t We'll Rave Again
# /t Crossing The Rubicon
# /t We'll Rave Again - Perc Remix
# /t We'll Rave Again - AXKAN Remix
# Remix Collection Vol.3
# /t Defect - Peter Van Hoesen's Twisted Spine Remix
# /t BCG - Milton Bradley Critical Level Remix
# /t Code#01 - Donor/Truss Remix
# /t Mathematical Accuracy - Norman Nodge Dub
# /t Beat The System - Russ Gabriel Remix
# /t Ode To The Elders - Perc Remix
# /t Work Softer - Matador Remix
# /t YouRso - Metalogic Remix
# /t Code By The Girl In Red - Sawf Remix
# /t Pink Body - Mr Magma Remix
# Vulkan Alarm!
# /t Vulkan Alarm!
# /t Vulkan Alarm! - Proxy Remix
# /t Vulkan Alarm! - Jan Driver Remix
# /t Vulkan Alarm! - Perc Remix
# Endless September
# /t Endless September
# /t Endless September - Perc Remix
# /t Endless September - Vapauteen Interlocking Mix
# /t Endless September - Vapauteen No News Is Good News Mix
# /t Endless September - Instrumental Mix
# /t Endless September - Perc Dub Mix
# Forthcoming EP - Random Remixxes v1
# /t Fin_droon - Perc Remixx
# /t FBP - Corbin Davis Edit
# /t FBP - Valvestat Edit
# /t FBP - Luis Ruiz Remixx
# Headless Horseman 002
# /t Decapitation
# /t Graveyard - Perc Remix
# /t Graveyard - Original Mix
# Speicher 56 - 61
# /t ...i Like
# /t Mylikestyle
# /t Headphone Heart
# /t Remember
# /t Get On Up There
# /t Pretty Face
# /t Tulipa
# /t Firewire
# /t Second Hand
# /t Hair Of The Dog
# /t Diamond Girl
# /t All Night Thing
# Soundzystem Vol. 2 (Mixed By Tony Senghore)
# /t The Essence - Jesper Dahlbäck Remix
# /t Twisted Route
# /t Trojan
# /t Let It Drop - Santos Diaboliqiue Electronique Remix
# /t Catwalk Red Sofa
# /t On Me - Tony Senghore's Jamais Vu Remix
# /t Grizzly - Lützenkirchen Latenight Dub
# /t Sound Like You
# /t I Want a Bud
# /t Genesis - Florian Kruse Remix
# /t Ulica Celna
# /t Tokyo Tokyo
# /t Poem
# /t Cleaning My Kalashnikov
# /t The 4:08 to Paris - Mooner Re-Edit
# /t Buttersaure - Perc Remix
# /t There's Life In Heavens Too
# /t Speaker Problems - Bass Mix
# /t Gamma - Perc's Gamma Dub
# /t Faster Pussycat Kill Kill - Tony Senghore's Munchkin Cat Instrumental
# /t Angels and Men
# /t 25 Timer
# /t Soundzystem Vol. 2 - Mixed By Tony Senghore
# A Is For Acid
# /t A Is For Acid - Perc Redux
# /t A Is For Acid - Perc Mod Mix
# /t A Is For Acid - MPIA3 Definition
# Perc Trax: Tracks Of 2022
# /t Dirt
# /t Junkyard Shift
# /t Aeon Core
# /t Sucker Punch
# /t Kiti Kimera
# /t Pitch-Hiker
# /t Rotopod
# /t Xegatron
# /t Warlion
# /t Ryu Acid
# 069 Techno Volume 2
# /t Trikeracing - Original Mix
# /t Zit - Joseph Capriati Remix
# /t Black Box - Original Mix
# /t Mean - Flug Remix
# /t Khamael - Hans Bouffmyhre Remix
# /t Aftertaste - Audio Injection Remix
# /t Sample42 - Original Mix
# /t Rhythm Slave - Original Mix
# /t Spaceworks - Remix
# /t Creaking Material - Original Mix
# /t Wrong - Original Mix
# MOB
# /t Bad guy
# /t Off da dome
# /t How you feelin
# /t Freeze (No fucks)
# /t Who did it
# /t Summn
# /t On my own
# /t Can't trip
# /t Army
# /t Story vivid
# /t No tax
# Faze #30: Terranova
# /t Faze DJ-Set 30
# /t Conjure Superstar
# /t Atomic Soda
# /t Sun Ritual
# /t You
# /t Lick the Pipe
# /t Take This
# /t Unstable Condition
# /t Painkiller - Michael Mayer Mix
# /t Up Tool
# /t Hawk Tone
# /t Tourette
# /t Happiness
# /t Goldfisch
# /t Windsurf, Sunburn and Dollar - Extended Raw Version
# /t Get On Up There
# Move Your Body / Hall of Mirrors (Perc & Truss Remixes)
# /t Move Your Body - Perc & Truss Remix
# /t Hall of Mirrors - Perc & Truss Remix
# No Hesi
# /t No Hesi
# Perc Trax: Tracks Of 2021
# /t Dumpster - EAS Remix
# /t London In My System
# /t Greed Dance
# /t Fist Fuck - Perc Remix
# /t You Puked In The Alley Where We Kissed
# /t Resistor
# /t Pivotal Summer
# /t Zero - Scalameriya Remix
# /t 240 Volts
# /t Persist & Change
# Remix Collection Vol.1
# /t Responsibility - Gary Beck Remix
# /t Work Harder - District One Remix
# /t Schlund - Bearweasel Mix
# /t Stolperfalle - Matador Remix
# /t Drifting - Perc Remix
# /t Bus Driver - Tolfrey & Sylvester OUT-Ed Remix
# /t Stalefish - Kyle Geiger Remix
# /t Timanfaya - Ozgur Can Remix
# /t Many Paths - Hertz Remix
# /t In Force - Spartak Remix
# 5 Years Of Sleaze Records
# /t ACB Experiment - Gary Beck Remix
# /t Noise A - Alan Fitzpatrick Remix
# /t Nohouse - Original Mix
# /t Toggle - Original Mix
# /t Level Me - Chris Liebing Remix
# /t Creepy - Joseph Capriati Remix
# /t Space - Gary Beck's Stripped Naked Tool
# /t Diatomic - Monoloc Remix
# /t Inside Of My Brain Cells - Original Mix
# /t Standing On My Foot - Grindvik By Your Side Remix
# /t Breathe - Original Mix
# /t Genetik - Original Mix
# /t Inside Your Soul - Drumcell Remix
# /t Sibling Rivalry - Original Mix
# /t Space - DVS1 Remix
# /t The Confession - Mark Broom Remix Version 2
# /t Laying Dormant - Cari Lekebusch Remix
# /t Turista - Jerome Sydenham Remix
# /t Identical Vocal Chords - Samuel L Session Remix
# /t Factor AG - Pfirter Remix
# /t Alperton Badass - Tony Rohr Remix
# /t Jobby Noir - Perc Remix
# The Beast Remix E.P.
# /t The Beast - Perc Remix
# /t The Beast
# Best Of Sleaze, Vol. 11
# /t Seb
# /t Mind Control - Wehbba Remix
# /t Land Of Nod
# /t Paretos Law - Robert S (PT) Remix
# /t Holographic
# /t Bleeds - Perc Remix
# /t Vasuki
# /t Voltaic - Petter B Remix
# /t Shit In Your Hands & Clap
# /t First Response
# /t Beloved Thug
# /t Revoke - 2000 And One Remix
# /t Sparse
# /t Fractures - Developer Remix
# /t Energy Raiz
# /t Second Phase - Version 1
# CLR Presents Mind Sets: Rebekah
# /t Empty
# /t The Gallery Of The Afterlife
# /t 2
# /t Backview - Xhei Remix
# /t Exiles
# /t Shaded
# /t Erosion 2
# /t The Choice is Mine - Rødhåd Remix
# /t Starbust
# /t Finding the Way
# /t Fusion Of Thoughts - Par Grindvik Rework
# /t Hardlines Soft Skin
# /t Grindr
# /t Infinite Abyss
# /t The Storm - L.A.W. Remix
# /t Program
# /t Wisdom of Youth
# /t Anonymous
# /t Zero Point.
# /t Gyre
# /t Rebuild Disintegrate
# /t Petrol
# /t Nevermind
# /t Surfaced
# /t Western Ways - Pfirter Remix
# /t Venus - Ciren Remix
# /t The Jellyfish
# /t B1
# /t Berkel
# /t Empire
# /t Blood Red
# /t CLR Presents Mind Sets: Rebekah - Continuous Mix
# Impacts
# /t Impacts
# /t Impacts - Gabe Gurnsey Factory Floor Remix
# /t Impacts - Perc Remix
# Stellate 1
# /t Estragon
# /t Vladimir
# /t Meet the Band
# /t The Seduction Ends in Tears
# /t Paris
# /t Molineux
# /t Frequency Phase - Pt. I & II
# /t Frequency Phase - Pt. III
# Defect
# /t Defect - Peter Van Hoesen's Twisted Spine Remix
# /t Defect - Perc Remix
# Remix Collection Vol.2
# /t Titleless - Ripperton's Placid Remix
# /t Trapjaw - Xpansul's Dub Mix
# /t Night In The Jungle - Matador Remix
# /t Numb - Max Cooper's Curve Mix
# /t Bliss - Simone Tavazzi Remix
# /t Wave After Wave - Sawf Remix
# /t Pink Body - Salmon Remix
# /t Vavasofa - Perc Remix
# /t Myself Myself - Metalogic's Disposition Mix
# /t Way In - Seake's Way Out Mix
# {B/A (2+3)} =(BRNSPACE/ANTHRSPACE 2+3)
# /t BENT (isagen’s BRKRmix)
# /t Brainspace (TriaMer Remix)
# /t Brainspace (CRZFxxK vo.l2 by CRZKNY)
# /t Brainspace (食品祭り a.k.a foodman REMIX)
# /t Brainspace (D.J.Fulltono Remix)
# /t Brainspace (BESTSELLER RMX)
# /t Brainspace (AX V MX)
# /t Brainspace (1980yen remix)
# /t Anotherspace
# /t Brainspace (DJ.DJ E/A/T Rmx Bерсия)
# /t Bent (hanali remix)
# /t Brainspace (Indus Bonze REMIX Part.2)
# /t Brainspace (Gorge Mix Franz Snake)
# /t Bent (AX Ambient Mix1)
# /t Distort VIII
# /t Distort IX
# /t Brainspice (Cycheouts Ghost skit)
# /t Brainspace (BODIL Remix)
# /t Brainspace (Devecly Bitte Remix)
# /t Bent (m3t4 "Enter the Hardcore" Rmx)
# /t Brainspace (perc Remix version)
# /t Anotherspace 4
# /t Bent (ToupemaMapeto Extended REMIX)
# /t Brainspace (Gutenberg Remix)
# /t Bent (AX Ambient Mix 2)
# /t Brainspace (AmbientHomo Ver.2)
# /t Distort X
# Soundzystem Vol. 1 (Mixed By Håkan Lidbo)
# /t An Evening With Bobi Bros
# /t When Flowers Talk
# /t Tokyo Tokyo
# /t Particolare
# /t Emitted
# /t Grizzly - Lützenkirchen Latenight Remix
# /t Sound Like Me
# /t Buttersaure - Perc Remix
# /t The Essence - Jesper Dahlbäck's DJ-Tool 1
# /t Trojan
# /t Speaker Problems - A Cappella
# /t Faster Pussycat Kill Kill - Tony Senghore's Hello Kitty Remix
# /t Profile Lost
# /t Genesis - Roberto Rodriguez Remix
# /t Soundzystem Vol.1 - Mixed By Håkan Lidbo
# TBO 2016
# /t The Man Is Just Confused - VSK Remix
# /t Chronology of Madness
# /t Crear Idolos
# /t Ectomorfo - Perc Remix
# /t Transgenic
# /t La Marche de la Lune Part 3
# /t Anxious
# /t Outline
# /t Fake Hill - Paul Birken Remix
# /t Unknown Perception
# /t Rymdfärder
# /t Opening Up - Aleja Sanchez Remix V1
# /t Challenger
# /t PMTL
# /t Unforgotten
# /t Retrig
# /t Ectomorfo - Kessell Remix
# /t Combined Figures
# /t Selling Out For Us
# /t Polar Exploration Day 1
# /t Ectomorfo - Kwartz Remix
# /t Anisocoria
# Rouge Noir
# /t Rouge Noir - Perc Remix
# /t Rouge Noir
# /t A Lighter Shade Of Pale
# Perc Trax - Tracks Of 2013
# /t A Is For Acid - Perc Redux
# /t Code#3
# /t Ruins
# /t Clapacid
# /t Diin
# /t Jettison
# /t Grid
# /t Spiker
# /t Grid - Mondkopf Elegie Remix
# /t Evacuation Route
# Ganymede
# /t Ganymede
# /t Ganymede - Perc Remix
# /t Ganymede - Skirt Remix
# /t Hackney
# /t Ganymede - Perc Dub
# Quemadura del Sol
# /t Quemadura del Sol
# /t Quemadura del Sol - Perc Remix
# /t Quemadura del Sol - Raiz Remix
# /t Quemadura del Sol - Luigi Madonna Remix
# /t Quemadura del Sol - Mada & Plankton Remix
# /t Quemadura del Sol - Subfractal Remix
# /t Quemadura del Sol - Tess Wassila Remix
# /t Quemadura del Sol - Jeff Keenan Remix
# /t Quemadura del Sol - Deepak Sharma & Dieter Krause Remix
# Eye 2 Eye
# /t Bo Nix
# /t No Hook
# /t We On
# /t Hold on Wait
# /t You Do Not Get It
# /t Shake It
# /t Neva Learn
# /t Wym
# /t With Me
# /t Moving Like That (Addition)
# /t Come Over
# Best Of Sleaze Vol.3
# /t ACB Experiment - Gary Beck Remix
# /t Nohouse - Original Mix
# /t Level Me - Chris Liebing Remix
# /t Creepy - Joseph Capriati Remix
# /t Genetik - Original Mix
# /t Toggle - Original Mix
# /t Brain Disease - Markantonio Remix
# /t M Cargo - Original Mix
# /t N2 - Mark Broom Remix
# /t Turista - Jerome Sydenham Remix
# /t Laying Dormant - Cari Lekebusch Remix
# /t Diatomic - Monoloc Remix
# /t Numbers - Original Mix
# /t No Reason - Audio Injection Remix
# /t Inside Your Soul - Drumcell Remix
# /t Wolfman - Original Mix
# /t Lost In Naples - Original Mix
# /t Synthetic - Original Mix
# Bored Machine Remixed
# /t A Trial - Secus Remix
# /t A Trial - Perc Remix
# /t Bored Machine - Josh Sturges Remix
# /t Bored Machine - Selective Response Remix
# Cox EP Vol.2
# /t It's U - Spartak Vs Perc Dub Mix
# /t Lovely Lovely Lovely - Lee Kavanagh Remix
# /t Lovely Lovely Lovely - Lee Kavanagh Instrumental Mix
# Ectomorfo
# /t Ectomorfo - Original Mix
# /t Ectomorfo - Kwartz Remix
# /t Ectomorfo - Kessell Remix
# /t Ectomorfo - Perc Remix
# CLR Presents Mind Sets: Rebekah - Sampler 1
# /t Grindr
# /t Shaded
# /t Erosion 2
# /t Finding the Way
# Flow Velocity EP
# /t Flow Velocity - Original Mix
# /t Flow Velocity - Perc Mix
# /t Flow Velocity - Andreas Kraemer Mix
# /t Flow Velocity - Mike Ban & Dietmar Wohl Mix
# /t Flow Velocity - Dandi & Ugo Mix
# /t Suton - Original Mix
# Best Of Sleaze Vol.1
# /t Minimal It - Original Mix
# /t Immobile - Original Mix
# /t Jack Move - Original Mix
# /t Riot Van - Original Mix
# /t Minimal It - Shin Nishimura's Discoteque Remix
# /t Immobile - Dandi & Ugo Remix
# /t Stone Dead - Gary Beck Remix
# /t Space Invaders - Seismal D. Remix
# /t Alperton Badass - Tony Rohr Remix
# /t Space Invaders - Uto Karem Remix
# /t Stormy Loop - Gennaro Mastrantonio Remix Version 2
# /t Jobby Noir - Perc Remix
# Tunnel Vision EP
# /t Sedition Chamber
# /t The Tunnel
# /t The Vision
# /t They Sex Machinas
# /t They Sex Machinas - Perc Remix
# /t They Sex Machinas - Perc's Dub Decision
# Four on the Floor
# /t Four on the Floor
# /t Four on the Floor - Perc Remix
# /t Four on the Floor - Perc's Dub Mix
# /t Four on the Floor - DJ Sneak Remix
# /t Four on the Floor - DJ Sneak Instrumental Remix
# /t Four on the Floor - Jean-Phi Goncalves' Beast Remix
# /t Four on the Floor - Shuttle Remix
# Guap Top
# /t Guap Top
# Perc Trax - Tracks Of 2012
# /t Hackney
# /t Labour Division
# /t Kneel
# /t A New Brutality
# /t Murder Top
# /t Magnetic
# /t Elegant Mistakes
# /t Passenger
# /t The Tunnel
# /t Xylem Teardrops
# Static Renegade
# /t Static Renegade - Original Mix
# /t Static Renegade - Perc Remix
# /t Indra - Original Mix
# /t Quango - The Cobble
# Best Of Sleaze Vol. 5
# /t Droning - Slam Paragraph Mix
# /t Pure & Simple - Ben Sims Warehouse Remix
# /t Shine - Original Mix
# /t Provoke - Shifted Remix
# /t Albatross - Original Mix
# /t Slumber - Dustin Zahn End Of Summer Remix
# /t Pure & Simple - Original Mix
# /t Warlocks - Harvey McKay Remix
# /t Self Destruct - Hans Bouffmyhre Remix
# /t Hidden - Original Mix
# /t Alpha Connection - Original Mix
# /t Underwall - Xpansul 2dapoint Remix
# /t Playing With Fire - Original Mix
# /t Egret - Alexi Delano Remix
# Rubicon
# /t Rubicon
# /t Rubicon - Perc's Green Assault Mix
# /t Rubicon - Perc's Ruby Red Mix
# As Long As The Moment Remixed, Vol. 1
# /t Sunday Is A Travel Day - Error Error Remix
# /t Stay Tuned - Alland Byallo V-Hold Remix
# /t Don't Hide What You Believe - Perc Trufax Remix
# /t Portion Control - Joel Mull Remix
# /t Belt Seat Fasten - Komposit Remix
# Strictly Techno Vol. 2
# /t Hōjō
# /t Untitled 1
# /t Function
# /t Apfelbraun
# /t Deep Space
# /t Beyond Earth
# /t PX02 - Perc Remix
# /t Anti-Mimesis 1
# /t Crossin' The Madmoon - 2019 Remaster
# /t Blue Sugar
# /t Outworld
# /t The Last Dark Cloud
# /t Proxy
# /t Acid Bang
# /t Changes
# Beta Sampler
# /t Wooden Art - Original Mix
# /t Trevisun - Original Mix
# /t My Visor - Original Mix
# /t Face2face with Reality - Original Mix
# Class Compliant
# /t PX02 - Perc Remix
# /t Heaven - Electric Rescue Remix
# /t Heaven
# /t Youth
# Sted-E & Hybrid Heights 2012 Club Mix EP
# /t Lift (feat. Sylvia Tosun)
# /t Timewarp (feat. PerC)
# /t Forever
# /t Futuristic Sound
# /t Roll Out
# Black Trip 2
# /t Coltrane - Kolombo Remix
# /t Discotico Desertico - Paulor Remix
# /t Capacite
# /t Time
# /t Flash
# /t The Vision
# /t Hasrat - Kotelett Melodic Remix
# /t U-Haul
# /t Afar - Joyhauser Remix
# /t Arkenstone
# /t Headphone Heart
# /t Cyprus Hills
# /t Winter
# /t Jupiter
# /t Cenere
# Cox EP
# /t It's U - Perc Remix
# /t Lovely Lovely Lovely - Switchshift Remix
# Remix Collection Vol. 6
# /t Unrhythm - Marcel Fengler Remix
# /t They Sex Machinas - Perc Remix
# /t Ganymede - Perc Remix
# /t Start Chopping - Tommy Four Seven Remix
# /t Mandate - Sawf Remix
# /t Nihil Novi - Michael Cliffe House Mix by Dom Factory Floor
# /t Grid - Mondkopf Litanie Remix
# /t Hear & Now - Jeff Derringer Revision
# /t Meltdown - Pinion Remix
# /t The Trail Of Your Blood In The Snow - Iori Remix
# Darkside Of Miami
# /t Darkside Of Miami - Original Mix
# /t Darkside Of Miami - Perc's EBM Love Remix
# /t Darkside Of Miami - Hans Bouffmyhre's Even Darker Remix
# /t Darkside Of Miami - Billy Johnston Remix
# Resampled, Pt. 2
# /t Wooden Art - Modern Heads Jumplex Remix
# /t Face2face with Reality - Frank Martiniq Defiance Remix
# /t Inside the Shadows - Dadub Metropolis Remix
# /t Abstract Subway - Claudio Prc Perspective Remix
# Liberty Way
# /t Intro (.FreeBabyDoe)
# /t Liberty Way
# /t I Can Tell
# /t Streets Need Me
# /t Grit Dumpin
# /t Liberty Brick
# /t Get It Or Not
# /t How You Want It
# /t Grit Talk
# /t Grit Files (.Bonus Track/RiugChubs)
# Full Of Fire
# /t Tha Bank
# /t 2 Ovalz
# /t Sorry 2 Sorry
# /t Wellfed
# Remix Collection Vol. 5
# /t Demon Within - Pfirter Remix
# /t BCG - Forward Strategy Group Remix
# /t Spirit of Elibop - Donor/Truss Remix
# /t Backshredding - Perc Remix
# /t The Glass Bead Game - Samuli Kemppi Remix
# /t Exit Sound - Milton Bradley Remix
# /t Osbasten - Tessela Remix
# /t Concrete Advance - Dead Sound & Videohead Remix
# /t 1909 - Millie's Dark Room Mix
# Does Not Mean EP
# /t Does Not Mean - Original Mix
# /t Does Not Mean - Perc Remix
# /t Polka Tribe - Octave Remix
# /t Core Damage - Original Mix
# /t Polka Tribe - Original Mix
# /t Does Not Mean - Perc's Kick Tool Mix
# Remix Collection Vol. 4
# /t Raw Jam - Jonas Kopp Remix
# /t Postmodern - Lucy Remix
# /t Backshredding - Forward Strategy Group Remix
# /t Bouncer - Perc Remix
# /t 1909 - Derek Plaslaiko Remix
# /t Tarantula - Iori's Dub Mix
# /t No Trace - Perc Remix
# /t Noson - Truss Dub
# /t Benwell - Sawf Remix
# /t Osbasten - Donor Remix
# Tribarhythm, Vol. 1
# /t B4 The Daybreak - Eddie Cuesta Remix
# /t Local Anesthesia - Gare Mat K Remix
# /t Acid Piano - Tamer Fouda Remix
# /t Momentum - Randall Jones Remix
# /t Ai - London 909 Remix
# /t Lady (Hear Me Tonight) - Guillermo Castillo Remix
# /t It's U - Perc Remix
# /t IC - 2002 Unreleased Mix
# /t Dream Yard
# /t Diamond Dust - Rabbit In The Moon Dub Mix
# Peak Time Techno, Vol. 15
# /t Build Back The Bad
# /t Relapse
# /t Artilleryman
# /t The Code
# /t Artifacts
# /t Niagara
# /t Passage 21
# /t Psychedelics - Blaper Remix
# /t Because - M. Rodriguez Remix
# /t Pyrexia In Pompey
# /t System Down
# /t Camp
# /t Battle Ground
# /t Damaged Brain
# /t Satanas - Nikita Remix
# /t Under the Influence
# /t Vice Grip
# /t Tycho - Bagagee Viphex13 Remix
# /t We'll Rave Again - Perc Remix
# /t Move Your Body
# /t System Sabotage
# /t Affection - Optimuss Acid Remix
# /t Strobe - iMiKe Remix
# /t Terraform
# /t PRTKL2
# Aeon
# /t Aeon
# /t Aeon - Perc remix
# /t Aeon - Perc dub
# Backshredding
# /t Backshredding - Forward Strategy Group Remix
# /t Backshredding - Perc Remix
# /t Backshredding - Remastered Mix
# Naughty Gold Vol. 4
# /t Benwell - Sawf Remix
# /t No Trace - Perc Remix
# /t Indifference 1 - Leo Cavallo Supine Hip Extension Remix
# Hostile Ground
# /t Hostile Ground
# /t Hostile Ground - Sterio & McGrath downtempo remix
# /t Hostile Ground - Perc remix
# Linda
# /t Linda
# Subsonic Species V3
# /t Interceptor - Perc Edit
# /t Forced Perspective Two
# /t Dub Notch
# /t Elm & Trumbull
# PURGAMENTUM
# /t Intro
# /t chapman
# /t гордый одиночка
# /t Мы всего добились сами
# /t На моих руках
# /t ШОУБИЗНЕСС - Interlude
# /t DRIVE
# /t биомусор
# /t Пёс
# /t Лучше не стой рядом
# /t bonus
# BRNSPACE/ANTHRSPACE
# /t Brainspace (Perc Remix)
# /t Brainspace (Kotoge Ryuei Remix)
# /t Bent (CRZKNY Jukeout Rmx)
# /t Brainspace (AX Motor MX)
# /t Brainspace (SKE REMIX)
# /t Brainspace (hanali Remix)
# /t Anotherspace
# /t Anotherspace 2
# /t Brainspace (m3t4 Rmx redux)
# /t Bent (Gorge Mix by Franz Snake)
# /t Brainspace (Original)
# /t Distort VI
# /t Distort VII
# /t Drilling (PV MX)
# My Phone
# /t My Phone
# Evaporate EP
# /t Evaporate - Original Mix
# /t Evaporate - Perc Remix
# /t No Dither - Original Mix
# Lovers Remorse
# /t Id0ntknow
# /t Perky Chills
# /t Never Needed L<3V
# /t 6ix0fMud
# /t W0ck In The Cream
# /t Need A New 1
# /t Not Sosa !
# /t Kamikaze !
# /t Cannot GiveAFuk
# /t Loved Me First
# /t Dead To Me
# /t Heal My Soul !
# /t Beautiful Sin
# /t Valentine's Day
# /t Succubus
# /t Dead Inside
# The Fifth Element
# /t Bumble's Collar
# /t Cellocommunicato
# /t Havsulven
# /t Bumble's Collar - Perc's flea collar dub
# /t Havsulven - Qbical Remix
# 20th Anniversary Tech Edition
# /t Impossible
# /t Fuck U - Miamix
# /t You Got Me Wrong - D-Unity Remix
# /t It's Not Important
# /t Ocean Drive 2014 - The YellowHeads Remix
# /t Remember - Adan Mor Remix
# /t It's U - Perc Remix
# /t High Stakes - Kobbe & Leeds Remix
# /t Diamond Dust - Rabbit In The Moon Dub Mix
# /t Local Anesthesia - Gare Mat K Remix
# /t B4 The Daybreak - Eddie Cuesta Remix
# /t Acid Piano - Tamer Fouda Remix
# /t Lady (Hear Me Tonight) - Guillermo Castillo Remix
# /t The Good Time - Notches Remix
# /t Lose Control - Erik Schievenin Remix
# /t Mother Earth - LeRon, Yves Eaux & Arnold From Mumbai Dub Mix
# /t Never Surrender - Mentality H Dub Mix
# /t Ready For Summer - Norbert Meszes Remix
# /t Keep It Down - Denis Zephyr Remix
# /t Ai - London 909 Remix
# Rusty Nail
# /t Rusty Nail - Original Mix
# /t Rusty Nail - Perc Remix
# /t Rusty Nail - Perc Rust Dub
# Ostrich EP
# /t Ostrich - Original Mix
# /t Ostrich - Perc Remix
# /t Ostrich - Perc's Beak Jack Dub
# /t Ostrich - Main ST. Dub Remix
# /t Ostrich - U.F.O / James Bacon Remix
# /t Non Dub - Original Mix
# Coded By The Girl In Red
# /t Coded By The Girl In Red - Input Mix
# /t Coded By The Girl In Red - Perc Remix
# /t Coded By The Girl In Red - Sawf Remix
# /t Coded By The Girl In Red - Output Mix
# Hengtuo ep
# /t Hengtuo - Original Mix
# /t Hengtuo - Perc Remix
# /t Hengtuo - Alejandro Trebor remix
# /t Hengtuo - Perc's Novox dub remix
# CLR Presents Mind Sets: Rebekah - Sampler 1
# /t Grindr
# /t Shaded
# /t Erosion 2
# /t Finding the Way

# %%
preview_url = 'https://p.scdn.co/mp3-preview/888e68f1dc95d8c9f0c963daf8b41d6b971fd60d?cid=d6893361042047bf884ef4a7e15eb14c'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
